# %% [markdown]
# # Classifying Stocks Using Machine Learning
# ## Collecting Richer Data
# <hr>
#
# The purpose of this notebook is to evaluate full articles for richer sentiment analysis, creating a related stock count, and completing tf-idf using a query list to parse if stocks may be projected to rise or fall.
#
# ### Objectives
#  - investigate most used article sites
#  - create collection methods for articles
#  - collect:
#      - sentiment
#      - related stocks mentioned in article
#      - captured text for tf-idf
#  - implement tf-idf scoring system
#  - implement collection of top adjacent stock news and social sent
#      - create new column for "related_stock_sent"
#  - export new df with columns:
#      - related_stock_sent
#      - tfidf_score
#      - full_article_sent

# %%
import pandas as pd
import numpy as np
from pycorenlp import StanfordCoreNLP
from collections import Counter
import requests
from bs4 import BeautifulSoup
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
import re
import urllib.request

# %%
df = pd.read_hdf('stocksFullCleaned.h5')

# %%
# get the amount of each source first

news = []
for i in df['source']:
    for i2 in i:
        news.append(i2)
news = dict(Counter(news))
len(news)
# Out:
# 330

# %%
news
# Out:
# {'SeekingAlpha': 7792,
#  'DowJones': 1822,
#  'MarketWatch': 7855,
#  'Reuters': 2120,
#  'Yahoo': 18524,
#  'Alliance News': 1382,
#  'TalkMarkets': 1932,
#  'Associated Press, The': 1191,
#  'Stock Options Channel': 184,
#  'CNBC': 4226,
#  'Investing.com': 1676,
#  'Thefly.com': 4252,
#  'GlobeNewswire': 92,
#  'InvestorPlace': 1960,
#  '247WallSt': 404,
#  'GuruFocus': 4168,
#  'Nasdaq': 7401,
#  'PR Newswire': 104,
#  'https://www.independent.co.uk': 13,
#  'Benzinga': 3212,
#  'benzinga': 588,
#  'United Press International': 108,
#  'PR Web': 446,
#  'Market News Video': 75,
#  'ETF Channel': 51,
#  'The Online Investor': 42,
#  'Business Wire': 174,
#  'https://www.arabnews.com': 28,
#  'abcnews': 99,
#  'businesswire': 464,
#  'https://www.einpresswire.com': 15,
#  'https://www.teslarati.com': 5,
#  'https://www.thelincolnianonline.com': 170,
#  'https://screenrant.com': 76,
#  'https://born2invest.com': 4,
#  'https://www.techtimes.com': 71,
#  'https://www.markets.co': 5,
#  'https://investorplace.com': 39,
#  'https://venturebeat.com': 17,
#  'https://www.indiatoday.in': 19,
#  'https://www.thestar.com': 30,
#  'https://invezz.com': 48,
#  'https://www.irishexaminer.com': 6,
#  'https://www.theedgemarkets.com': 15,
#  'https://www.livemint.com': 33,
#  'https://www.zonebourse.com': 21,
#  'https://indianexpress.com': 32,
#  'https://www.marketscreener.com': 120,
#  'https://www.upi.com': 15,
#  'https://www.smartcompany.com.au': 5,
#  'https://www.businessinsider.es': 39,
#  'https://lawandcrime.com': 6,
#  'https://www.capital.fr': 16,
#  'https://www.lemonde.fr': 36,
#  'https://www.bnnbloomberg.ca': 39,
#  'https://www.fool.com': 159,
#  'https://www.ibtimes.com': 20,
#  'https://www.benzinga.com': 9,
#  'https://www.businessinsider.in': 76,
#  'https://www.reuters.com': 10,
#  'https://www.lalibre.be': 9,
#  'https://www.insurancejournal.com': 4,
#  'https://www.freemalaysiatoday.com': 20,
#  'https://www.devdiscourse.com': 26,
#  'https://www.clarin.com': 49,
#  'https://www.pionline.com': 2,
#  'https://www.boursorama.com': 15,
#  'https://rp-online.de': 3,
#  'https://www.financialexpress.com': 15,
#  'https://www.afr.com': 5,
#  'https://www.cp24.com': 21,
#  'https://www.oregonlive.com': 12,
#  'https://www.slashgear.com': 32,
#  'https://www.theepochtimes.com': 33,
#  'https://www.eveningexpress.co.uk': 7,
#  'https://learnbonds.com': 59,
#  'https://zeenews.india.com': 22,
#  'https://www.business-standard.com': 4,
#  'The Guardian': 187,
#  'https://www.forbes.com': 98,
#  'https://www.moneyweb.co.za': 5,
#  'https://ain.ua': 10,
#  'https://www.economist.com': 6,
#  'Preferred Stock Channel': 20,
#  'Energy Stock Channel': 2,
#  'https://advisorhub.com': 1,
#  'https://gulfbusiness.com': 4,
#  'https://www.cityam.com': 5,
#  'https://www.fnarena.com': 1,
#  'https://news.bitcoin.com': 5,
#  'https://www.paymentsjournal.com': 3,
#  'https://www.fool.com.au': 2,
#  'https://www.nytimes.com': 17,
#  'https://www.crowdfundinsider.com': 2,
#  'https://cnnespanol.cnn.com': 20,
#  'https://www.americanbanker.com': 2,
#  'https://www.siliconrepublic.com': 9,
#  'https://impactalpha.com': 1,
#  'https://www.risk.net': 1,
#  'https://time.com': 1,
#  'Dividend Channel': 17,
#  'https://deadline.com': 16,
#  'https://www.channelfutures.com': 14,
#  'https://www.smarteranalyst.com': 6,
#  'https://www.al.com': 5,
#  'https://etfdailynews.com': 2,
#  'https://elliottwave-forecast.com': 1,
#  'Bloomberg': 9,
#  'https://insidebitcoins.com': 1,
#  'https://www.investmentnews.com': 1,
#  'https://www.theglobeandmail.com': 18,
#  'https://cleantechnica.com': 10,
#  'https://www.oilandgas360.com': 1,
#  'https://www.axios.com': 4,
#  'https://moneymorning.com': 2,
#  'https://www.theage.com.au': 2,
#  'https://www.antaranews.com': 23,
#  'https://www.nj.com': 2,
#  'http://www.stocksequity.com': 4,
#  'https://www.digitaltrends.com': 31,
#  'https://nypost.com': 18,
#  'https://www.forbes.com.mx': 23,
#  'https://www.vulture.com': 7,
#  'https://thehill.com': 30,
#  'https://www.presstelegram.com': 17,
#  'https://www.nbcnews.com': 11,
#  'https://www.ansa.it': 23,
#  'https://bgr.com': 22,
#  'https://www.techradar.com': 29,
#  'https://www.coinspeaker.com': 9,
#  'https://www.hindustantimes.com': 25,
#  'https://www.express.co.uk': 28,
#  'https://www.reviewed.com': 3,
#  'https://www.mirror.co.uk': 9,
#  'https://www.lavanguardia.com': 20,
#  'https://www.devonlive.com': 1,
#  'https://g1.globo.com': 19,
#  'https://www.breitbart.com': 28,
#  'https://www.eluniversal.com.co': 12,
#  'https://www.pressherald.com': 15,
#  'https://www.ctvnews.ca': 15,
#  'cnet': 2,
#  'https://www.androidcentral.com': 21,
#  'https://www.washingtonpost.com': 17,
#  'https://www.theverge.com': 71,
#  'https://www.srf.ch': 4,
#  'https://www.elconfidencial.com': 12,
#  'https://www.businessinsider.fr': 16,
#  'https://www.plymouthherald.co.uk': 2,
#  'https://elpais.com': 15,
#  'https://www.sudinfo.be': 13,
#  'https://www.dailystar.co.uk': 3,
#  'https://news.alphastreet.com': 7,
#  'https://9to5mac.com': 22,
#  'https://yourstory.com': 3,
#  'https://www.abc.es': 5,
#  'https://footwearnews.com': 30,
#  'https://9to5toys.com': 6,
#  'https://www.ino.com': 1,
#  'https://www.bostonglobe.com': 6,
#  'https://www.gobankingrates.com': 11,
#  'https://www.thisismoney.co.uk': 4,
#  'https://pagesix.com': 3,
#  'https://www.elmundo.es': 8,
#  'https://www.cleveland.com': 3,
#  'https://thenewswheel.com': 23,
#  'https://www.dailymail.co.uk': 20,
#  'https://www.cnbc.com': 5,
#  'https://www.dailysabah.com': 11,
#  'https://apnews.com': 2,
#  'https://www.elperiodico.com': 15,
#  'https://nairametrics.com': 2,
#  'http://www.irishnews.com': 5,
#  'https://patch.com': 13,
#  'https://www.washingtonexaminer.com': 18,
#  'https://www.hulldailymail.co.uk': 1,
#  'https://www.examinerlive.co.uk': 2,
#  'https://en.trend.az': 2,
#  'https://electrek.co': 4,
#  'https://thewest.com.au': 1,
#  'https://7news.com.au': 5,
#  'https://betakit.com': 3,
#  'https://www.rte.ie': 4,
#  'https://www.irishtimes.com': 10,
#  'https://cincodias.elpais.com': 13,
#  'https://sevilla.abc.es': 6,
#  'https://www.manchestereveningnews.co.uk': 4,
#  'https://www.leicestermercury.co.uk': 1,
#  'https://computerworld.com.br': 9,
#  'https://inews.co.uk': 4,
#  'https://www.dailyrecord.co.uk': 5,
#  'https://www.iol.co.za': 7,
#  'https://www.diepresse.com': 2,
#  'https://www.entrepreneur.com': 17,
#  'https://www.thecable.ng': 7,
#  'https://www.thequint.com': 4,
#  'https://www.thedailybeast.com': 4,
#  'https://timesofindia.indiatimes.com': 56,
#  'https://www.irishnews.com': 3,
#  'https://www.thesouthafrican.com': 3,
#  'https://www.em.com.br': 2,
#  'https://www.thestar.com.my': 8,
#  'https://www.thestreet.com': 1,
#  'https://www.bbc.com': 6,
#  'https://www.lesechos.fr': 10,
#  'https://thefinancialbrand.com': 1,
#  'https://www.straitstimes.com': 16,
#  'https://themalaysianreserve.com': 8,
#  'https://www.news18.com': 8,
#  'https://www.dnaindia.com': 2,
#  'https://www.smh.com.au': 3,
#  'https://www.nakedcapitalism.com': 1,
#  'https://www.indiatvnews.com': 11,
#  'https://www.windowscentral.com': 126,
#  'https://www.zeebiz.com': 5,
#  'https://www.cultofmac.com': 4,
#  'https://analyticsindiamag.com': 10,
#  'https://www.courrierinternational.com': 6,
#  'https://extra.ie': 8,
#  'https://www.france24.com': 5,
#  'https://beincrypto.com': 4,
#  'https://www.techzim.co.zw': 4,
#  'https://alltop.com': 1,
#  'https://news.artnet.com': 1,
#  'https://techcentral.co.za': 9,
#  'https://www.nationalreview.com': 8,
#  'https://www.poynter.org': 8,
#  'https://www.20min.ch': 5,
#  'https://www.datacenterknowledge.com': 4,
#  'https://www.latribune.fr': 4,
#  'https://npengage.com': 1,
#  'https://www.larazon.es': 10,
#  'https://www.suredividend.com': 5,
#  'https://grizzle.com': 1,
#  'https://www.vanguardngr.com': 2,
#  'https://graceandlightness.com': 1,
#  'https://coingape.com': 2,
#  'https://www.standard.net': 2,
#  'https://www.mylondon.news': 1,
#  'https://www.blick.ch': 3,
#  'https://www.noen.at': 1,
#  'https://www.theguardian.com': 2,
#  'https://www.dhnet.be': 5,
#  'https://www.profitconfidential.com': 2,
#  'https://m.businesstoday.in': 4,
#  'https://bizwatchnigeria.ng': 2,
#  'https://www.ndtv.com': 1,
#  'https://www.newtimes.co.rw': 1,
#  'https://www.fool.co.uk': 5,
#  'https://www.batimes.com.ar': 1,
#  'https://tech.co': 3,
#  'https://www.channelnews.fr': 2,
#  'https://www.thestatesman.com': 1,
#  'https://www.lemondeinformatique.fr': 19,
#  'https://arynews.tv': 2,
#  'https://www.lecho.be': 12,
#  'https://www.capitalfm.co.ke': 2,
#  'https://business.lesechos.fr': 1,
#  'https://www.breizh-info.com': 1,
#  'https://mobile.reuters.com': 1,
#  'https://www.abc.net.au': 1,
#  'http://jamaica-gleaner.com': 1,
#  'https://cryptobriefing.com': 3,
#  'YAHOO': 1,
#  'https://blogs.intel.com': 19,
#  'https://www.lesoir.be': 2,
#  'https://www.pcworld.com': 16,
#  'https://insidebigdata.com': 1,
#  'https://www.nottinghampost.com': 1,
#  'https://www.extremetech.com': 14,
#  'https://www.ipwatchdog.com': 3,
#  'https://www.getreading.co.uk': 1,
#  'https://blocksandfiles.com': 2,
#  'https://smallbiztrends.com': 1,
#  'https://realmoney.thestreet.com': 4,
#  'https://www.irishmirror.ie': 4,
#  'https://www.rcrwireless.com': 9,
#  'https://stratechery.com': 1,
#  'https://www.thurrott.com': 10,
#  'https://www.itweb.co.za': 3,
#  'https://www.somersetlive.co.uk': 1,
#  'https://www.counterpointresearch.com': 1,
#  'https://www.plasticstoday.com': 1,
#  'https://www.finder.com.au': 3,
#  'https://www.analyticsvidhya.com': 1,
#  'https://khn.org': 4,
#  'https://www.dividenddiplomats.com': 1,
#  'https://www.elcorreo.com': 3,
#  'https://www.thereporter.com': 1,
#  'https://fr.metrotime.be': 3,
#  'https://plus.lesoir.be': 1,
#  'https://edition.cnn.com': 2,
#  'https://www.infomoney.com.br': 3,
#  'https://www.news.com.au': 1,
#  'https://9to5google.com': 2,
#  'https://thefintechtimes.com': 1,
#  'https://www.helpnetsecurity.com': 7,
#  'https://www.thelondoneconomic.com': 1,
#  'https://www.ots.at': 2,
#  'https://www.businessinsider.com.au': 2,
#  'https://hbr.org': 2,
#  'https://blogs.vmware.com': 1,
#  'https://112.international': 2,
#  'https://sneakernews.com': 27,
#  'https://www.liverpoolecho.co.uk': 3,
#  'https://www.schaeffersresearch.com': 1,
#  'https://yen.com.gh': 1,
#  'https://www.standard.co.uk': 2,
#  'https://www.coventrytelegraph.net': 1,
#  'https://www.alternet.org': 2,
#  'https://pharmaphorum.com': 1,
#  'https://www.statnews.com': 2,
#  'https://medcitynews.com': 2,
#  'https://www.lancs.live': 1,
#  'https://www.gloucestershirelive.co.uk': 1,
#  'https://www.walesonline.co.uk': 1,
#  'https://africanmanager.com': 1,
#  'https://www.huffpost.com': 1,
#  'https://www.coindesk.com': 4,
#  'https://coingeek.com': 1,
#  'https://finovate.com': 1,
#  'https://cryptopotato.com': 1,
#  'https://dailyhodl.com': 1,
#  'https://www.livebitcoinnews.com': 1,
#  'https://zycrypto.com': 1,
#  'https://cointelegraph.com': 1,
#  'https://www.eveningtelegraph.co.uk': 1,
#  'https://www.bristolpost.co.uk': 1,
#  'https://www.agefi.fr': 1,
#  'https://www.marketwatch.com': 1}

# %%
news = {k: v for k, v in sorted(news.items(), key=lambda item: item[1],reverse=True)}
news
# Out:
# {'Yahoo': 18524,
#  'MarketWatch': 7855,
#  'SeekingAlpha': 7792,
#  'Nasdaq': 7401,
#  'Thefly.com': 4252,
#  'CNBC': 4226,
#  'GuruFocus': 4168,
#  'Benzinga': 3212,
#  'Reuters': 2120,
#  'InvestorPlace': 1960,
#  'TalkMarkets': 1932,
#  'DowJones': 1822,
#  'Investing.com': 1676,
#  'Alliance News': 1382,
#  'Associated Press, The': 1191,
#  'benzinga': 588,
#  'businesswire': 464,
#  'PR Web': 446,
#  '247WallSt': 404,
#  'The Guardian': 187,
#  'Stock Options Channel': 184,
#  'Business Wire': 174,
#  'https://www.thelincolnianonline.com': 170,
#  'https://www.fool.com': 159,
#  'https://www.windowscentral.com': 126,
#  'https://www.marketscreener.com': 120,
#  'United Press International': 108,
#  'PR Newswire': 104,
#  'abcnews': 99,
#  'https://www.forbes.com': 98,
#  'GlobeNewswire': 92,
#  'https://screenrant.com': 76,
#  'https://www.businessinsider.in': 76,
#  'Market News Video': 75,
#  'https://www.techtimes.com': 71,
#  'https://www.theverge.com': 71,
#  'https://learnbonds.com': 59,
#  'https://timesofindia.indiatimes.com': 56,
#  'ETF Channel': 51,
#  'https://www.clarin.com': 49,
#  'https://invezz.com': 48,
#  'The Online Investor': 42,
#  'https://investorplace.com': 39,
#  'https://www.businessinsider.es': 39,
#  'https://www.bnnbloomberg.ca': 39,
#  'https://www.lemonde.fr': 36,
#  'https://www.livemint.com': 33,
#  'https://www.theepochtimes.com': 33,
#  'https://indianexpress.com': 32,
#  'https://www.slashgear.com': 32,
#  'https://www.digitaltrends.com': 31,
#  'https://www.thestar.com': 30,
#  'https://thehill.com': 30,
#  'https://footwearnews.com': 30,
#  'https://www.techradar.com': 29,
#  'https://www.arabnews.com': 28,
#  'https://www.express.co.uk': 28,
#  'https://www.breitbart.com': 28,
#  'https://sneakernews.com': 27,
#  'https://www.devdiscourse.com': 26,
#  'https://www.hindustantimes.com': 25,
#  'https://www.antaranews.com': 23,
#  'https://www.forbes.com.mx': 23,
#  'https://www.ansa.it': 23,
#  'https://thenewswheel.com': 23,
#  'https://zeenews.india.com': 22,
#  'https://bgr.com': 22,
#  'https://9to5mac.com': 22,
#  'https://www.zonebourse.com': 21,
#  'https://www.cp24.com': 21,
#  'https://www.androidcentral.com': 21,
#  'https://www.ibtimes.com': 20,
#  'https://www.freemalaysiatoday.com': 20,
#  'Preferred Stock Channel': 20,
#  'https://cnnespanol.cnn.com': 20,
#  'https://www.lavanguardia.com': 20,
#  'https://www.dailymail.co.uk': 20,
#  'https://www.indiatoday.in': 19,
#  'https://g1.globo.com': 19,
#  'https://www.lemondeinformatique.fr': 19,
#  'https://blogs.intel.com': 19,
#  'https://www.theglobeandmail.com': 18,
#  'https://nypost.com': 18,
#  'https://www.washingtonexaminer.com': 18,
#  'https://venturebeat.com': 17,
#  'https://www.nytimes.com': 17,
#  'Dividend Channel': 17,
#  'https://www.presstelegram.com': 17,
#  'https://www.washingtonpost.com': 17,
#  'https://www.entrepreneur.com': 17,
#  'https://www.capital.fr': 16,
#  'https://deadline.com': 16,
#  'https://www.businessinsider.fr': 16,
#  'https://www.straitstimes.com': 16,
#  'https://www.pcworld.com': 16,
#  'https://www.einpresswire.com': 15,
#  'https://www.theedgemarkets.com': 15,
#  'https://www.upi.com': 15,
#  'https://www.boursorama.com': 15,
#  'https://www.financialexpress.com': 15,
#  'https://www.pressherald.com': 15,
#  'https://www.ctvnews.ca': 15,
#  'https://elpais.com': 15,
#  'https://www.elperiodico.com': 15,
#  'https://www.channelfutures.com': 14,
#  'https://www.extremetech.com': 14,
#  'https://www.independent.co.uk': 13,
#  'https://www.sudinfo.be': 13,
#  'https://patch.com': 13,
#  'https://cincodias.elpais.com': 13,
#  'https://www.oregonlive.com': 12,
#  'https://www.eluniversal.com.co': 12,
#  'https://www.elconfidencial.com': 12,
#  'https://www.lecho.be': 12,
#  'https://www.nbcnews.com': 11,
#  'https://www.gobankingrates.com': 11,
#  'https://www.dailysabah.com': 11,
#  'https://www.indiatvnews.com': 11,
#  'https://www.reuters.com': 10,
#  'https://ain.ua': 10,
#  'https://cleantechnica.com': 10,
#  'https://www.irishtimes.com': 10,
#  'https://www.lesechos.fr': 10,
#  'https://analyticsindiamag.com': 10,
#  'https://www.larazon.es': 10,
#  'https://www.thurrott.com': 10,
#  'https://www.benzinga.com': 9,
#  'https://www.lalibre.be': 9,
#  'https://www.siliconrepublic.com': 9,
#  'Bloomberg': 9,
#  'https://www.coinspeaker.com': 9,
#  'https://www.mirror.co.uk': 9,
#  'https://computerworld.com.br': 9,
#  'https://techcentral.co.za': 9,
#  'https://www.rcrwireless.com': 9,
#  'https://www.elmundo.es': 8,
#  'https://www.thestar.com.my': 8,
#  'https://themalaysianreserve.com': 8,
#  'https://www.news18.com': 8,
#  'https://extra.ie': 8,
#  'https://www.nationalreview.com': 8,
#  'https://www.poynter.org': 8,
#  'https://www.eveningexpress.co.uk': 7,
#  'https://www.vulture.com': 7,
#  'https://news.alphastreet.com': 7,
#  'https://www.iol.co.za': 7,
#  'https://www.thecable.ng': 7,
#  'https://www.helpnetsecurity.com': 7,
#  'https://www.irishexaminer.com': 6,
#  'https://lawandcrime.com': 6,
#  'https://www.economist.com': 6,
#  'https://www.smarteranalyst.com': 6,
#  'https://9to5toys.com': 6,
#  'https://www.bostonglobe.com': 6,
#  'https://sevilla.abc.es': 6,
#  'https://www.bbc.com': 6,
#  'https://www.courrierinternational.com': 6,
#  'https://www.teslarati.com': 5,
#  'https://www.markets.co': 5,
#  'https://www.smartcompany.com.au': 5,
#  'https://www.afr.com': 5,
#  'https://www.moneyweb.co.za': 5,
#  'https://www.cityam.com': 5,
#  'https://news.bitcoin.com': 5,
#  'https://www.al.com': 5,
#  'https://www.abc.es': 5,
#  'https://www.cnbc.com': 5,
#  'http://www.irishnews.com': 5,
#  'https://7news.com.au': 5,
#  'https://www.dailyrecord.co.uk': 5,
#  'https://www.zeebiz.com': 5,
#  'https://www.france24.com': 5,
#  'https://www.20min.ch': 5,
#  'https://www.suredividend.com': 5,
#  'https://www.dhnet.be': 5,
#  'https://www.fool.co.uk': 5,
#  'https://born2invest.com': 4,
#  'https://www.insurancejournal.com': 4,
#  'https://www.business-standard.com': 4,
#  'https://gulfbusiness.com': 4,
#  'https://www.axios.com': 4,
#  'http://www.stocksequity.com': 4,
#  'https://www.srf.ch': 4,
#  'https://www.thisismoney.co.uk': 4,
#  'https://electrek.co': 4,
#  'https://www.rte.ie': 4,
#  'https://www.manchestereveningnews.co.uk': 4,
#  'https://inews.co.uk': 4,
#  'https://www.thequint.com': 4,
#  'https://www.thedailybeast.com': 4,
#  'https://www.cultofmac.com': 4,
#  'https://beincrypto.com': 4,
#  'https://www.techzim.co.zw': 4,
#  'https://www.datacenterknowledge.com': 4,
#  'https://www.latribune.fr': 4,
#  'https://m.businesstoday.in': 4,
#  'https://realmoney.thestreet.com': 4,
#  'https://www.irishmirror.ie': 4,
#  'https://khn.org': 4,
#  'https://www.coindesk.com': 4,
#  'https://rp-online.de': 3,
#  'https://www.paymentsjournal.com': 3,
#  'https://www.reviewed.com': 3,
#  'https://www.dailystar.co.uk': 3,
#  'https://yourstory.com': 3,
#  'https://pagesix.com': 3,
#  'https://www.cleveland.com': 3,
#  'https://betakit.com': 3,
#  'https://www.irishnews.com': 3,
#  'https://www.thesouthafrican.com': 3,
#  'https://www.smh.com.au': 3,
#  'https://www.blick.ch': 3,
#  'https://tech.co': 3,
#  'https://cryptobriefing.com': 3,
#  'https://www.ipwatchdog.com': 3,
#  'https://www.itweb.co.za': 3,
#  'https://www.finder.com.au': 3,
#  'https://www.elcorreo.com': 3,
#  'https://fr.metrotime.be': 3,
#  'https://www.infomoney.com.br': 3,
#  'https://www.liverpoolecho.co.uk': 3,
#  'https://www.pionline.com': 2,
#  'Energy Stock Channel': 2,
#  'https://www.fool.com.au': 2,
#  'https://www.crowdfundinsider.com': 2,
#  'https://www.americanbanker.com': 2,
#  'https://etfdailynews.com': 2,
#  'https://moneymorning.com': 2,
#  'https://www.theage.com.au': 2,
#  'https://www.nj.com': 2,
#  'cnet': 2,
#  'https://www.plymouthherald.co.uk': 2,
#  'https://apnews.com': 2,
#  'https://nairametrics.com': 2,
#  'https://www.examinerlive.co.uk': 2,
#  'https://en.trend.az': 2,
#  'https://www.diepresse.com': 2,
#  'https://www.em.com.br': 2,
#  'https://www.dnaindia.com': 2,
#  'https://www.vanguardngr.com': 2,
#  'https://coingape.com': 2,
#  'https://www.standard.net': 2,
#  'https://www.theguardian.com': 2,
#  'https://www.profitconfidential.com': 2,
#  'https://bizwatchnigeria.ng': 2,
#  'https://www.channelnews.fr': 2,
#  'https://arynews.tv': 2,
#  'https://www.capitalfm.co.ke': 2,
#  'https://www.lesoir.be': 2,
#  'https://blocksandfiles.com': 2,
#  'https://edition.cnn.com': 2,
#  'https://9to5google.com': 2,
#  'https://www.ots.at': 2,
#  'https://www.businessinsider.com.au': 2,
#  'https://hbr.org': 2,
#  'https://112.international': 2,
#  'https://www.standard.co.uk': 2,
#  'https://www.alternet.org': 2,
#  'https://www.statnews.com': 2,
#  'https://medcitynews.com': 2,
#  'https://advisorhub.com': 1,
#  'https://www.fnarena.com': 1,
#  'https://impactalpha.com': 1,
#  'https://www.risk.net': 1,
#  'https://time.com': 1,
#  'https://elliottwave-forecast.com': 1,
#  'https://insidebitcoins.com': 1,
#  'https://www.investmentnews.com': 1,
#  'https://www.oilandgas360.com': 1,
#  'https://www.devonlive.com': 1,
#  'https://www.ino.com': 1,
#  'https://www.hulldailymail.co.uk': 1,
#  'https://thewest.com.au': 1,
#  'https://www.leicestermercury.co.uk': 1,
#  'https://www.thestreet.com': 1,
#  'https://thefinancialbrand.com': 1,
#  'https://www.nakedcapitalism.com': 1,
#  'https://alltop.com': 1,
#  'https://news.artnet.com': 1,
#  'https://npengage.com': 1,
#  'https://grizzle.com': 1,
#  'https://graceandlightness.com': 1,
#  'https://www.mylondon.news': 1,
#  'https://www.noen.at': 1,
#  'https://www.ndtv.com': 1,
#  'https://www.newtimes.co.rw': 1,
#  'https://www.batimes.com.ar': 1,
#  'https://www.thestatesman.com': 1,
#  'https://business.lesechos.fr': 1,
#  'https://www.breizh-info.com': 1,
#  'https://mobile.reuters.com': 1,
#  'https://www.abc.net.au': 1,
#  'http://jamaica-gleaner.com': 1,
#  'YAHOO': 1,
#  'https://insidebigdata.com': 1,
#  'https://www.nottinghampost.com': 1,
#  'https://www.getreading.co.uk': 1,
#  'https://smallbiztrends.com': 1,
#  'https://stratechery.com': 1,
#  'https://www.somersetlive.co.uk': 1,
#  'https://www.counterpointresearch.com': 1,
#  'https://www.plasticstoday.com': 1,
#  'https://www.analyticsvidhya.com': 1,
#  'https://www.dividenddiplomats.com': 1,
#  'https://www.thereporter.com': 1,
#  'https://plus.lesoir.be': 1,
#  'https://www.news.com.au': 1,
#  'https://thefintechtimes.com': 1,
#  'https://www.thelondoneconomic.com': 1,
#  'https://blogs.vmware.com': 1,
#  'https://www.schaeffersresearch.com': 1,
#  'https://yen.com.gh': 1,
#  'https://www.coventrytelegraph.net': 1,
#  'https://pharmaphorum.com': 1,
#  'https://www.lancs.live': 1,
#  'https://www.gloucestershirelive.co.uk': 1,
#  'https://www.walesonline.co.uk': 1,
#  'https://africanmanager.com': 1,
#  'https://www.huffpost.com': 1,
#  'https://coingeek.com': 1,
#  'https://finovate.com': 1,
#  'https://cryptopotato.com': 1,
#  'https://dailyhodl.com': 1,
#  'https://www.livebitcoinnews.com': 1,
#  'https://zycrypto.com': 1,
#  'https://cointelegraph.com': 1,
#  'https://www.eveningtelegraph.co.uk': 1,
#  'https://www.bristolpost.co.uk': 1,
#  'https://www.agefi.fr': 1,
#  'https://www.marketwatch.com': 1}

# %%
top20 = sum(list(news.values())[:20])
top15 = sum(list(news.values())[:15])
top10 = sum(list(news.values())[:10])
top5 = sum(list(news.values())[:5])

# %%
values = news.values()
total = sum(values)

# %%
total
# Out:
# 75980

# %%
# top 20 will give us 94% coverage
# if its a lot of work, top15 would be good enough
# keeping us at > 90%

print(top20/total)
print(top15/total)
print(top10/total)
print(top5/total)
# Out:
# 0.9423795735719926
# 0.9148854961832061
# 0.8095551460910766
# 0.6031060805475125

# %%
# we need to get links to top 20 articles, we can start with yahoo

top20keys = list(news.keys())[:20]

# %%
# sentiment analyzer (download lexicon if needed)

# nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()

# %%
def findNewsRows(source):
    articleRows = []
    for idx,row in df.iterrows():
        for i in row["source"]:
            if i == source:
                articleRows.append(idx)
    unqArt = []
    for i in articleRows:
        if i not in unqArt:
            unqArt.append(i)
    return unqArt

# %%
def printUrls(idx):
    a = df.iloc[idx]["source"]
    b = df.iloc[idx]["url"]
    urlPair = []
    for i in range(len(a)):
        urlPair.append([a[i],b[i]])
    return urlPair

# %%
b = findNewsRows(top20keys[11])
b
# Out:
# [0,
#  2,
#  19,
#  20,
#  21,
#  27,
#  30,
#  31,
#  39,
#  45,
#  57,
#  70,
#  81,
#  82,
#  85,
#  89,
#  101,
#  103,
#  109,
#  115,
#  123,
#  124,
#  125,
#  130,
#  133,
#  134,
#  138,
#  139,
#  144,
#  145,
#  146,
#  148,
#  150,
#  151,
#  152,
#  154,
#  157,
#  158,
#  159,
#  161,
#  162,
#  164,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  175,
#  176,
#  177,
#  178,
#  180,
#  181,
#  182,
#  184,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  218,
#  220,
#  221,
#  224,
#  226,
#  230,
#  232,
#  233,
#  234,
#  236,
#  237,
#  238,
#  240,
#  241,
#  242,
#  247,
#  248,
#  250,
#  251,
#  254,
#  255,
#  256,
#  257,
#  303,
#  304,
#  305,
#  306,
#  312,
#  313,
#  318,
#  319,
#  320,
#  321,
#  326,
#  339,
#  340,
#  346,
#  348,
#  349,
#  350,
#  357,
#  360,
#  378,
#  379,
#  380,
#  381,
#  382,
#  384,
#  385,
#  386,
#  395,
#  400,
#  401,
#  403,
#  406,
#  408,
#  410,
#  413,
#  415,
#  420,
#  421,
#  423,
#  425,
#  428,
#  432,
#  453,
#  454,
#  459,
#  467,
#  468,
#  540,
#  544,
#  551,
#  567,
#  572,
#  606,
#  659,
#  681,
#  683,
#  694,
#  695,
#  700,
#  701,
#  704,
#  705,
#  714,
#  717,
#  721,
#  724,
#  731,
#  732,
#  733,
#  746,
#  747,
#  761,
#  770,
#  773,
#  774,
#  776,
#  777,
#  789,
#  790,
#  791,
#  793,
#  803,
#  804,
#  805,
#  814,
#  816,
#  818,
#  819,
#  824,
#  826,
#  829,
#  834,
#  835,
#  850,
#  851,
#  852,
#  853,
#  854,
#  868,
#  881,
#  902,
#  905,
#  928,
#  929,
#  932,
#  937,
#  939,
#  948,
#  949,
#  950,
#  953,
#  957,
#  959,
#  960,
#  961,
#  963,
#  965,
#  966,
#  967,
#  973,
#  977,
#  979,
#  980,
#  984,
#  986,
#  992,
#  998,
#  1004,
#  1006,
#  1007,
#  1010,
#  1033,
#  1034,
#  1036,
#  1040,
#  1041,
#  1042,
#  1043,
#  1052,
#  1064,
#  1065,
#  1068,
#  1069,
#  1073,
#  1076,
#  1094,
#  1105,
#  1113,
#  1116,
#  1119,
#  1125,
#  1127,
#  1128,
#  1129,
#  1159,
#  1162,
#  1180,
#  1181,
#  1183,
#  1196,
#  1203,
#  1205,
#  1206,
#  1209,
#  1211,
#  1212,
#  1213,
#  1214,
#  1219,
#  1226,
#  1227,
#  1231,
#  1233,
#  1235,
#  1236,
#  1237,
#  1238,
#  1240,
#  1241,
#  1251,
#  1254,
#  1257,
#  1259,
#  1261,
#  1281,
#  1283,
#  1288,
#  1289,
#  1290,
#  1291,
#  1293,
#  1297,
#  1300,
#  1301,
#  1304,
#  1309,
#  1310,
#  1312,
#  1314,
#  1316,
#  1317,
#  1321,
#  1330,
#  1337,
#  1361,
#  1367,
#  1372,
#  1375,
#  1376,
#  1390,
#  1417,
#  1420,
#  1423,
#  1425,
#  1429,
#  1440,
#  1445,
#  1451,
#  1453,
#  1454,
#  1455,
#  1456,
#  1461,
#  1464,
#  1479,
#  1483,
#  1504,
#  1604,
#  1608,
#  1672,
#  1692,
#  1722,
#  1732,
#  1754,
#  1808,
#  1822,
#  1837,
#  1842,
#  1854,
#  1857,
#  1858,
#  1871,
#  1909,
#  1920,
#  1933,
#  1934,
#  1955,
#  1960,
#  1967,
#  1991,
#  1995,
#  1997,
#  2041,
#  2083,
#  2087,
#  2089,
#  2099,
#  2104,
#  2107,
#  2108,
#  2109,
#  2113,
#  2114,
#  2121,
#  2122,
#  2130,
#  2137,
#  2138,
#  2173,
#  2191,
#  2192,
#  2194,
#  2195,
#  2196,
#  2208,
#  2209,
#  2215,
#  2216,
#  2220,
#  2225,
#  2232,
#  2235,
#  2237,
#  2244,
#  2249,
#  2253,
#  2264,
#  2269,
#  2270,
#  2271,
#  2283,
#  2329,
#  2331,
#  2334,
#  2341,
#  2350,
#  2351,
#  2352,
#  2399,
#  2400,
#  2423,
#  2427,
#  2442,
#  2469,
#  2470,
#  2471,
#  2472,
#  2479,
#  2485,
#  2489,
#  2493,
#  2494,
#  2495,
#  2497,
#  2503,
#  2504,
#  2506,
#  2510,
#  2511,
#  2512,
#  2513,
#  2516,
#  2518,
#  2519,
#  2559,
#  2572,
#  2573,
#  2577,
#  2579,
#  2593,
#  2594,
#  2595,
#  2597,
#  2599,
#  2600,
#  2603,
#  2605,
#  2606,
#  2607,
#  2608,
#  2609,
#  2610,
#  2611,
#  2613,
#  2615,
#  2616,
#  2617,
#  2621,
#  2623,
#  2624,
#  2628,
#  2629,
#  2630,
#  2631,
#  2632,
#  2634,
#  2635,
#  2636,
#  2638,
#  2640,
#  2641,
#  2642,
#  2643,
#  2646,
#  2648,
#  2649,
#  2650,
#  2651,
#  2652,
#  2653,
#  2654,
#  2655,
#  2656,
#  2657,
#  2660,
#  2661,
#  2663,
#  2664,
#  2665,
#  2666,
#  2686,
#  2687,
#  2689,
#  2690,
#  2695,
#  2697,
#  2703,
#  2704,
#  2705,
#  2709,
#  2710,
#  2711,
#  2712,
#  2713,
#  2714,
#  2716,
#  2717,
#  2718,
#  2719,
#  2720,
#  2721,
#  2725,
#  2726,
#  2727,
#  2729,
#  2730,
#  2731,
#  2733,
#  2734,
#  2735,
#  2737,
#  2738,
#  2739,
#  2740,
#  2744,
#  2751,
#  2752,
#  2756,
#  2762,
#  2783,
#  2805,
#  2813,
#  2814,
#  2829,
#  2831,
#  2841,
#  2856,
#  2857,
#  2858,
#  2860,
#  2868,
#  2873,
#  2876,
#  2877,
#  2878,
#  2879,
#  2880,
#  2881,
#  2883,
#  2884,
#  2893,
#  2898,
#  2904,
#  2907,
#  2911,
#  2913,
#  2925,
#  2926,
#  2943,
#  2952,
#  2953,
#  2955,
#  2961,
#  2963,
#  2971,
#  2978,
#  3036,
#  3087,
#  3097,
#  3107,
#  3171,
#  3178,
#  3188,
#  3190,
#  3290,
#  3291,
#  3295,
#  3296,
#  3297,
#  3298,
#  3303,
#  3305,
#  3311,
#  3312,
#  3313,
#  3314,
#  3315,
#  3316,
#  3324,
#  3325,
#  3326,
#  3337,
#  3344,
#  3382,
#  3389,
#  3405,
#  3406,
#  3407,
#  3409,
#  3412,
#  3413,
#  3416,
#  3417,
#  3422,
#  3425,
#  3427,
#  3428,
#  3429,
#  3430,
#  3432,
#  3435,
#  3439,
#  3440,
#  3441,
#  3444,
#  3446,
#  3448,
#  3449,
#  3450,
#  3452,
#  3453,
#  3454,
#  3456,
#  3458,
#  3459,
#  3460,
#  3461,
#  3463,
#  3464,
#  3465,
#  3466,
#  3469,
#  3472,
#  3476,
#  3477,
#  3479,
#  3480,
#  3481,
#  3484,
#  3501,
#  3509,
#  3510,
#  3511,
#  3515,
#  3516,
#  3524,
#  3528,
#  3530,
#  3531,
#  3544,
#  3545,
#  3548,
#  3549,
#  3550,
#  3551,
#  3557,
#  3558,
#  3559,
#  3561,
#  3565,
#  3566,
#  3569,
#  3574,
#  3576,
#  3577,
#  3578,
#  3584,
#  3586,
#  3590,
#  3591,
#  3592,
#  3595,
#  3596,
#  3598,
#  3600,
#  3603,
#  3604,
#  3605,
#  3606,
#  3611,
#  3612,
#  3614,
#  3617,
#  3618,
#  3619,
#  3620,
#  3642,
#  3644,
#  3647,
#  3648,
#  3650,
#  3651,
#  3652,
#  3653,
#  3654,
#  3655,
#  3659,
#  3661,
#  3664,
#  3665,
#  3666,
#  3667,
#  3669,
#  3670,
#  3673,
#  3674,
#  3676,
#  3678,
#  3679,
#  3680,
#  3681,
#  3682,
#  3683,
#  3686,
#  3687,
#  3688,
#  3689,
#  3690,
#  3691,
#  3693,
#  3695,
#  3696,
#  3734,
#  3745,
#  3756,
#  3822,
#  3840,
#  3841,
#  3843,
#  3861,
#  3917,
#  3944,
#  3960,
#  3980,
#  3985,
#  3989,
#  3993,
#  4007,
#  4027,
#  4041,
#  4049,
#  4051,
#  4060,
#  4066,
#  4069,
#  4077,
#  4078,
#  4092,
#  4115,
#  4116,
#  4152,
#  4174,
#  4191,
#  4204,
#  4206,
#  4209,
#  4210,
#  4213,
#  4215,
#  4217,
#  4219,
#  4228,
#  4231,
#  4236,
#  4249,
#  4250,
#  4252,
#  4288,
#  4289,
#  4290,
#  4297,
#  4298,
#  4302,
#  4303,
#  4306,
#  4310,
#  4314,
#  4316,
#  4318,
#  4319,
#  4323,
#  4324,
#  4332,
#  4333,
#  4336,
#  4339,
#  4343,
#  4345,
#  4346,
#  4347,
#  4348,
#  4349,
#  4353,
#  4354,
#  4355,
#  4361,
#  4366,
#  4367,
#  4370,
#  4374,
#  4380,
#  4381,
#  4382,
#  4384,
#  4385,
#  4387,
#  4393,
#  4394,
#  4412,
#  4419,
#  4424,
#  4426,
#  4437,
#  4438,
#  4439,
#  4440,
#  4441,
#  4442,
#  4443,
#  4448,
#  4451,
#  4452,
#  4453,
#  4457,
#  4459,
#  4461,
#  4464,
#  4466,
#  4468,
#  4470,
#  4472,
#  4473,
#  4474,
#  4475,
#  4477,
#  4482,
#  4493,
#  4494,
#  4500,
#  4570,
#  4571,
#  4578,
#  4581,
#  4605,
#  4606,
#  4611,
#  4617,
#  4618,
#  4625,
#  4626,
#  4630,
#  4640,
#  4654,
#  4685,
#  4687,
#  4696,
#  4709,
#  4718,
#  4732,
#  4733,
#  4752,
#  4775,
#  4836,
#  4852,
#  4854,
#  4855,
#  4914,
#  4915,
#  4944,
#  4947,
#  4954,
#  4955,
#  4957,
#  4958,
#  4959,
#  4960,
#  4961,
#  4962,
#  4963,
#  4966,
#  4968,
#  4969,
#  4970,
#  4971,
#  4972,
#  4976,
#  4978,
#  4979,
#  4982,
#  4983,
#  4984,
#  4985,
#  4986,
#  4989,
#  4991,
#  4993,
#  4996,
#  4998,
#  4999,
#  5002,
#  5003,
#  5004,
#  5005,
#  5006,
#  5007,
#  5008,
#  5009,
#  5010,
#  5011,
#  5012,
#  5013,
#  5014,
#  5015,
#  5016,
#  5017,
#  5032,
#  5033,
#  5037,
#  5039,
#  5042,
#  5045,
#  5048,
#  5049,
#  5054,
#  5056,
#  5059,
#  5060,
#  5061,
#  5062,
#  5067,
#  5068,
#  5069,
#  5070,
#  5072,
#  5073,
#  5074,
#  5077,
#  5080,
#  5082,
#  5083,
#  5084,
#  5085,
#  5086,
#  5087,
#  5088,
#  5089,
#  5090,
#  5091,
#  5093,
#  5094,
#  5095,
#  5108,
#  5117,
#  5118,
#  5121,
#  5129,
#  5132,
#  5143,
#  5189,
#  5216,
#  5217,
#  5223,
#  5224,
#  5237,
#  5243,
#  5244,
#  5250,
#  5277,
#  5278,
#  5279,
#  5325,
#  5329,
#  5335,
#  5357,
#  5358,
#  5365,
#  5366,
#  5371,
#  5378,
#  5382,
#  5383,
#  5384,
#  5388,
#  5398,
#  5400,
#  5412,
#  5415,
#  5417,
#  5418,
#  5420,
#  5421,
#  5424,
#  5425,
#  5426,
#  5443,
#  5445,
#  5451,
#  5458,
#  5474,
#  5485,
#  5486,
#  5494,
#  5497,
#  5506,
#  5512,
#  5532,
#  5543,
#  5544,
#  5547,
#  5548,
#  5563,
#  5616,
#  5617,
#  5622,
#  5623,
#  5624,
#  5625,
#  5626,
#  ...]

# %%
a = printUrls(123)

for i in a:
    print(i)
# Out:
# ['DowJones', 'https://finnhub.io/api/news?id=7c402ec87cbba4c75195c0a4cf31a517f207c0b27fab97b41d67dfd9aa33ecca']
# ['MarketWatch', 'https://finnhub.io/api/news?id=67f823db3f6de09760361ee570ce88036b4c7d77a06694fc920e527aa948c253']
# ['Benzinga', 'https://finnhub.io/api/news?id=2eb33a4edce904c28b4e1f8a5c7585ea3290b4f10a1784ba58b32fb64e690ce8']
# ['DowJones', 'https://finnhub.io/api/news?id=9a5d98919c885657d69d605051a1dee4806912b943f2846f5a899e5097fbb42e']
# ['MarketWatch', 'https://finnhub.io/api/news?id=ed3f8587b9f6f6a2879db3b4385061e61e92b50fb281862f8934c4a03d932873']
# ['benzinga', 'https://finnhub.io/api/news?id=e3f65917153a62d7424e5b4d686808073c893cb2090d76c43f4f4b0827f83704']
# ['MarketWatch', 'https://finnhub.io/api/news?id=639a2debe2064eb8980bc41b98c3207adee6abf4417cea15ef3798f30472f6e3']
# ['Benzinga', 'https://finnhub.io/api/news?id=6d9d5591f08f3b83c1b0ed6756c427b96a7a340d0dfc0a15c85bbed4042e9a59']
# ['benzinga', 'https://finnhub.io/api/news?id=35fe53b354c706dc97f77424d26c14a1d070b0c0842cc83e35d967fc7966c338']
# ['MarketWatch', 'https://finnhub.io/api/news?id=02e1145c986aea7af51b9c5159593d3e18412facd809b1967289fa4a0fbcf527']
# ['Benzinga', 'https://finnhub.io/api/news?id=915e8a1dd093d74804b36755463aa7f12413c69edb215c28cfb4df2b84ebe71c']
# ['benzinga', 'https://finnhub.io/api/news?id=a3a45e240bec2123b6df4079631c3e70d06c89b63d2cf44fc54531f4187a0c85']
# ['Benzinga', 'https://finnhub.io/api/news?id=c0bdfeac16c530592d2d9de3b8b578bd9f6d540c3e5d4b314a2c9e621a9af815']
# ['benzinga', 'https://finnhub.io/api/news?id=cf4d090f68f81dd87733197780d0e5e33dbcab713e85acc4446886cf28989d55']
# ['DowJones', 'https://finnhub.io/api/news?id=a63cae991a96aedc68b67acfee55d073f60b299d4bd8efcbab1a5d43c9a7da40']
# ['benzinga', 'https://finnhub.io/api/news?id=1dfc76ac744e7cf942fbb5c80d793fc1e0a2e646ef30bddef831e6237ebc6c23']
# ['SeekingAlpha', 'https://finnhub.io/api/news?id=942ec66304f9f30c85a79cc156b7e982a14f66b92a05c6e55a0c2ee002a81248']
# ['Benzinga', 'https://finnhub.io/api/news?id=a0cd596df85eca53fc206c8eee515cdd5064dab7a75c0ccc5449a0c19d4d9159']
# ['SeekingAlpha', 'https://finnhub.io/api/news?id=d1e448d3b0ac353ff1e1504ebd3d7e98ecd478c2822f588765ae0bf564179276']
# ['SeekingAlpha', 'https://finnhub.io/api/news?id=7b0493421ef2ed853bf0ed9ea0409bc4177b4fab43fb824188c48078bb3ed15c']
# ['benzinga', 'https://finnhub.io/api/news?id=6c749d3d9c897475d99ebaba8533ba935b79307dc9c3add142a0d26fdf7143e3']
# ['benzinga', 'https://finnhub.io/api/news?id=13c404b91bcc0dac940ec817186a882440c1e0a8e2f1e0f7e97811bb72ffc4a0']
# ['Benzinga', 'https://finnhub.io/api/news?id=cc70463c143a2896f2884588c35be002dd90c3889c1db34dcafa759ab868dcfd']

# %%
def collectHTML(url):
    headers = {"User-Agent":"Mozilla/5.0"}
    r = requests.get(url,headers=headers)
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup

# %%
def pYahoo(soup):
    outButton = soup.find_all("div", {"class": "caas-readmore caas-readmore-collapse caas-readmore-outsidebody caas-readmore-asidepresent"})
    if not outButton:
        body = soup.find("div", {"class": "caas-body"})
        paras = body.find_all("p")
    article = " ".join(str(i.text) for i in paras)
    relstocks = soup.find("ul", {"class": "caas-xray-pills xray-as-popup caas-xray-pills-top"})
    tickers = relstocks.find_all("li")
    stocks = []
    for i in tickers:
        stocks.append(i.text)
    sent = sia.polarity_scores(article)
    return article, stocks, sent['compound']

# %%
u = 'https://finance.yahoo.com/news/southwest-ceo-gary-kelly-is-euphoric-about-airline-recovery-191342217.html'

soup = collectHTML(u)

# %%
body = soup.find("div", {"class": "caas-body"})

# %%
paras = body.find_all("p")

# %%
# collecting yahoo articles
u = 'https://finance.yahoo.com/news/airlines-wont-call-travelers-covid-19-vaccination-proof-vaccine-passports-110015915.html'

soup = collectHTML(u)
a,b,c = pYahoo(soup)

# %%
u = 'https://www.marketwatch.com/articles/airline-stocks-are-soaring-as-leisure-travel-keeps-growing-51615829245'
soup = collectHTML(u)

# %%
content = soup.find("div", {"class": "column column--full article__content"})

# %%
def pMWatch(soup):
    content = soup.find("div", {"class": "column column--full article__content"})
    c = re.sub('\s+',' ',content.text)
    article = c.strip()
    
    tickers = soup.find("ul", {"class": "list list--tickers"})
    stock = tickers.find_all("bg-quote")
    itir = -1
    stocks = []
    for i in stock:
        itir=itir+1
        if itir%2 == 0:
            strp = re.sub('\s+',' ',i.text)
            a = strp.split()
            stocks.append(a[0].strip())
            
    sent = sia.polarity_scores(article)
    return article, stocks, sent['compound']

# %%
# collecting marketwatch articles
u = 'https://www.marketwatch.com/story/american-airlines-group-inc-stock-underperforms-tuesday-when-compared-to-competitors-01615926803-1d77385fe932'

soup = collectHTML(u)
a,b,c = pMWatch(soup)

# %%
u = "https://finnhub.io/api/news?id=c022d52df61b43d33425f3185eb0cc168b3b5b67a997f40c6ce9cd7fc8c95f94"

soup = collectHTML(u)

# %%
content = soup.find("div", {"class": "body__content"})
c = re.sub('\s+',' ',content.text)
article = c.strip()

# %%
ticks = soup.find("section", {"class": "topics-in-this-story"})
texts = ticks.find_all("a")

# %%
for i in texts:
    print(i.text)
# Out:
# BHP
# AAL
# RIO
# TER

# %%
def pNasdaq(soup):
    content = soup.find("div", {"class": "body__content"})
    c = re.sub('\s+',' ',content.text)
    article = c.strip()
    
    ticks = soup.find("section", {"class": "topics-in-this-story"})
    texts = ticks.find_all("a")
    stocks = []
    for i in texts:
        stocks.append(i.text)
    
    sent = sia.polarity_scores(article)
    return article, stocks, sent['compound']

# %%
# collecting Nasdaq articles
u = 'https://finnhub.io/api/news?id=c022d52df61b43d33425f3185eb0cc168b3b5b67a997f40c6ce9cd7fc8c95f94'

soup = collectHTML(u)
a,b,c = pNasdaq(soup)

# %%
c
# Out:
# 0.9804

# %%
content = soup.find("td", {"class": "newsContent"})
content.find("h1").text
# Out:
# 'American Airlines: Future cash flow to be used to reduce debt'

# %%
def pFly(soup):
    content = soup.find("td", {"class": "newsContent"})
    article = content.find("h1").text
    sent = sia.polarity_scores(article)
    
    return article, [], sent["compound"]

# %%
# collecting theFly articles
u = "https://thefly.com/landingPageNews.php?id=3287478&headline=AAL-American-Airlines-Future-cash-flow-to-be-used-to-reduce-debt"
soup = collectHTML(u)

a,b,c = pFly(soup)

# %%
u = "https://www.cnbc.com/2021/04/22/what-to-watch-today-us-stock-futures-steady-after-a-wall-street-comeback.html"

soup = collectHTML(u)

# %%
def pCNBC(soup):
    try:
        content = soup.find("div", {"class": "ArticleBody-articleBody"})
        article = re.sub('\s+',' ',content.text)
        sent = sia.polarity_scores(article)

        return article, [], sent["compound"]
    except:
        return '',[],0

# %%
# collecting cnbc articles
u = "https://www.cnbc.com/2021/04/22/what-to-watch-today-us-stock-futures-steady-after-a-wall-street-comeback.html"

soup = collectHTML(u)
a,b,c = pCNBC(soup)

# %%
u = "https://www.gurufocus.com/news/1405876/anglo-american-plc-stock-shows-every-sign-of-being-significantly-overvalued"

soup = collectHTML(u)

# %%
content = soup.find("div", {"class": "main-body"})

# %%
content.text

def pGuru(soup):
    content = soup.find("div", {"class": "main-body"})
    article = content.text
    sent = sia.polarity_scores(article)
    
    return article, [], sent["compound"]

# %%
# collecting guru articles
u = "https://www.gurufocus.com/news/1412285/wedbush-morgan-securities-inc-buys-vanguard-sp-500-etf-ishares-short-treasury-bond-etf-apple-inc-sells-pimco-enhanced-short-maturity-active-exchangetrad-aecom-allianzgi-artificial-intelligence-technology-opp"

soup = collectHTML(u)
a,b,c = pGuru(soup)

# %%
u = "https://www.benzinga.com/news/21/03/20282484/10-information-technology-stocks-with-unusual-options-alerts-in-todays-session"

soup = collectHTML(u)

# %%
content = soup.find("div", {"class": "article-content-body-only"})

# %%
article = re.sub('\s+',' ',content.text)

# %%
def pBzinga(soup):
    content = soup.find("div", {"class": "article-content-body-only"})
    article = re.sub('\s+',' ',content.text)
    article = article.strip()
    
    sent = sia.polarity_scores(article)
    return article, [], sent["compound"]

# %%
# collecting benzinga articles
u = "https://www.benzinga.com/news/21/03/20286063/the-qqq-rallied-today-heres-why"

soup = collectHTML(u)
a,b,c = pBzinga(soup)

# %%
u = "https://www.reuters.com/article/us-health-coronavirus-american-airline/american-airlines-readies-more-jets-to-meet-rising-demand-idUSKBN2BL21K"

soup = collectHTML(u)

# %%
content = soup.find("div", {"class": "ArticleBodyWrapper"})
c = content.find_all("p",{"class": "Paragraph-paragraph-2Bgue ArticleBody-para-TD_9x"})

# %%
article = ''
for i in c:
    article = article + " " + i.text
    
article = article.strip()
# Out:
# (Reuters) - American Airlines said on Monday it expects to fly most of its fleet in the coming months thanks to strong domestic and short-haul international bookings as COVID-19 infection rates and hospitalizations decline and more people receive vaccines. American said that as of March 26, average bookings for the next seven days had reached 90% of levels experienced before the pandemic upended air travel in 2019, with a domestic load factor of about 80%. “The Company presently expects this strength in bookings to continue through the end of the first quarter and into the second quarter,” it said in a regulatory filing. Shares in U.S. airlines, which parked hundreds of jets as demand plummeted last year, have climbed this year amid hopes for a recovery. The U.S. Transportation Security Administration (TSA) screened 1.57 million passengers on Sunday, the highest number since March 2020. Following the increase in travel demand so far this year, American said it expects its system capacity to be down between 40% and 45% in the first quarter to March 31 versus the same period in 2019, compared to its previous guidance for a 45% decline.

# %%
def pReuters(soup):
    content = soup.find("div", {"class": "ArticleBodyWrapper"})
    c = content.find_all("p",{"class": "Paragraph-paragraph-2Bgue ArticleBody-para-TD_9x"})
    article = ''
    for i in c:
        article = article + " " + i.text

    article = article.strip()
    
    sent = sia.polarity_scores(article)
    return article, [], sent["compound"]

# %%
# collecting reuters articles
u = "https://www.reuters.com/article/us-american-airlines-debt/american-airlines-cuts-debt-by-2-8-billion-idUSKBN2BN3DX"

soup = collectHTML(u)
a,b,c = pReuters(soup)

# %%
# Out:
# 0.6249

# %%
u = "https://investorplace.com/2021/04/midday-market-update-the-10-most-active-stocks-today-3/"

soup = collectHTML(u)

content = soup.find("div", {"class": "col-xs article"})

# %%
content.text
# Out:
# '\n\nFriday is halfway over and that means it’s time to measure up the stocks seeing the most movement today in our midday market update. We’re seeing a lot of tech stocks show up on the list today with many of them seeing share prices rising.\n\n'

# %%
def pInvPlace(soup):
    content = soup.find("div", {"class": "col-xs article"})
    article = re.sub('\s+',' ',content.text)
    article = article.strip()
    
    sent = sia.polarity_scores(article)
    return article, [], sent["compound"]

# %%
# collecting investorplace articles
u = "https://investorplace.com/2021/05/3-consumer-cyclical-stocks-to-buy-for-the-coming-travel-explosion/"

soup = collectHTML(u)
a,b,c = pInvPlace(soup)

# %%
c
# Out:
# 0.9986

# %%
u = "https://www.wsj.com/articles/google-to-lower-service-fee-for-play-store-app-developers-11615907010"

soup = collectHTML(u)

content = soup.find("div", {"class": "wsj-snippet-body"})

# %%
content.text
# Out:
# '\nGoogle is reducing the cut it takes from app sales in its Play store, joining rival  Apple Inc.  in shrinking commissions as the power the tech giants wield through their digital marketplaces has drawn the ire of developers and scrutiny of regulators. \nThe company behind the world’s largest mobile operating system, Android, said Tuesday that it would reduce service fee it collects from 30% to 15% on the first $1 million developers earn from its app store. The reduction, which begins in July, is a slight departure from  Apple Inc . ’s decision late last year to reduce its rate to 15% for software makers who generate less than $1 million in annual sales.\nGoogle, the main business of  Alphabet Inc.,  and Apple have built multibillion-dollar digital empires over the past decade by becoming the primary gatekeepers for apps that are downloaded to smartphones and other mobile devices world-wide. Their position of power has drawn criticism from developers large and small over the amount of money that tech companies are able to siphon from them. Those complaints have triggered lawsuits as well as regulatory probes in multiple countries. \nBy reducing its take of app sales, Google estimates that 99% of developers would see their fees cut in half. It said that every developer, regardless of size, is eligible to benefit, adding in a blog post that it considered the reduction to be “a fair approach that aligns our success with that of our developer ecosystem.”\nSome software makers panned Google’s decision. Tim Sweeney, an outspoken critic of app-marketplace operators as chief executive of “Fortnite” maker Epic Games Inc., described the move as a “self-serving gambit.”\n'

# %%
def pDowjones(soup):
    content = soup.find("div", {"class": "wsj-snippet-body"})
    article = re.sub('\s+',' ',content.text)
    article = article.strip()
    
    sent = sia.polarity_scores(article)
    return article, [], sent["compound"]

# %%
# collecting dow articles
u = "https://www.wsj.com/articles/american-jetblue-alliance-draws-increased-scrutiny-from-justice-department-11618423182"

soup = collectHTML(u)
a,b,c = pDowjones(soup)

# %%
a
# Out:
# 'WASHINGTON—The Justice Department has stepped up an antitrust probe of American Airlines Group Inc.’s recent partnership with JetBlue Airways Corp. and is concerned the deal could lead to anticompetitive coordination and inflated fares at key traffic hubs, according to people familiar with the matter. Department antitrust officials harbored reservations about the deal before the recent change in presidential administrations, but their scrutiny of the alliance has increased in recent months, the people said, an early signal of the Biden administration’s interest in antitrust enforcement. The department is concerned that an American-JetBlue alliance could diminish competition at congested Northeast airports in New York and Boston that are hubs for travel around the U.S. and internationally. The investigation is continuing and no final conclusions have been reached. Any Justice Department decision could be affected by the views of the Transportation Department, which has broad regulatory authority over the industry and signed off on the partnership in the waning days of the Trump administration. The Transportation Department is facing a public request from Spirit Airlines Inc. for a full and formal investigation of the American-JetBlue agreement, a move that could allow for reconsideration of the agency’s prior views. “The department is evaluating the record and will announce, in the next few months, action that it intends to take in this matter,” a DOT spokesperson said. A Justice Department spokeswoman declined to comment.'
